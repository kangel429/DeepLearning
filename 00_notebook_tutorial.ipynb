# %% [markdown]
# <a href="https://colab.research.google.com/github/kangel429/DeepLearning/blob/master/00_notebook_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
# !ls '/content/gdrive/My Drive/Colab Notebooks/course-v3-master/zh-nbs'
# Out:
# 00_notebook_tutorial.ipynb  lesson1-pets.ipynb

# %%
# !git clone https://github.com/kangel429/DeepLearning.git '/gdrive/My Drive/Colab Notebooks/course-v3-master/zh-nbs'
# Out:
# fatal: destination path '/gdrive/My Drive/Colab Notebooks/course-v3-master/zh-nbs' already exists and is not an empty directory.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
img_dir = "/content/gdrive/My Drive/Colab Notebooks/course-v3-master/nbs/dl1/images/notebook_tutorial/cat.jpg"
# Out:
# Mounted at /content/gdrive

# %%
# !ls "/content/gdrive/My Drive/Colab Notebooks/course-v3-master/nbs/dl1/images/notebook_tutorial/cat_example.jpg"
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/course-v3-master/nbs/dl1/images/notebook_tutorial/cat_example.jpg'

# %%
100+320
# Out:
# 420

# %%
222/2
# Out:
# 111.0

# %% [markdown]
# # **텍스트 테스트**
#
# *기울임*
#
# **진한 글씨**
#
# `인라인`
#
# [링크](https://)
#
# ![이미지](https://)
#
#
#
# > 들여쓴 블록
#
# 1.   항목 추가
#
#   - [ ] 항목 추가
#
#   - [x] 항목 추가
#
#
# 2.   항목 추가

# %%
# Import necessary libraries
from fastai.vision import * 
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
a = 3
b = a + 1
c = b / a + 2
d = c * b + a + 2
a, b, c ,d
# Out:
# (3, 4, 3.333333333333333, 18.333333333333332)

# %%
plt.plot([a,b,c,d])
plt.show()

# %%
Image.open(img_dir)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x7FFB11287898>

# %%
from fastai import*
from fastai.vision import *

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
# %timeit [i+1 for i in range(1000)]
# Out:
# 10000 loops, best of 3: 45.4 µs per loop

# %%
for i in range(1000):
    a = i+1
    b = 'string'
    c = b+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-8d78ff778454> in <module>()
#       2     a = i+1
#       3     b = 'string'
# ----> 4     c = b+1
#
# TypeError: must be str, not int

# %%
# %debug
# Out:
# > <ipython-input-39-8d78ff778454>(4)<module>()
#       1 for i in range(1000):
#       2     a = i+1
#       3     b = 'string'
# ----> 4     c = b+1
